# %% [markdown]
# # Intermediate Machine Learning with sklearn

# %% [markdown]
# ## 1. Simple linear regression

# %%
# libraries import
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
# load the data
df = sns.load_dataset('tips')
# select the feature column from df
X = df[['total_bill']]
# select the target column from df
y = df['tip']
# load/call the linear regression model
model = LinearRegression()
# fit the model means train the model
model.fit(X, y)
# lets predict the tip for an unknown total_bill
model.predict([[35.527]])
# Out:
# c:\Users\aammar\miniconda3\envs\python_ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.65147564])

# %%
sns.lmplot(x='total_bill', y='tip', data=df)

# %% [markdown]
# ## Multiple linear regression or Multilinear regression

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# libraries import
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
# load the data
df = sns.load_dataset('tips')
# select the feature column from df
X = df[['total_bill', 'size']]
# select the target column from df
y = df['tip']
# load/call the linear regression model
model = LinearRegression()
# fit the model means train the model
model.fit(X, y)
# lets predict the tip for an unknown total_bill
model.predict([[35.527, 2]])
# Out:
# c:\Users\aammar\miniconda3\envs\python_ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.34796705])

# %%
# libraries import
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
# load the data
df = sns.load_dataset('tips')
df.head()
# encode smoker column
df['smoker_num'] = df['smoker'].map({'Yes': 1, 'No': 0})
df.head()

# select the feature column from df
X = df[['total_bill', 'size', 'smoker_num']]
# select the target column from df
y = df['tip']
# load/call the linear regression model
model = LinearRegression()
# fit the model means train the model
model.fit(X, y)
# lets predict the tip for an unknown total_bill
print(model.predict([[35.527, 5, 1]]))
print(model.predict([[35.527, 5, 0]]))
# Out:
# [4.8628136]
# [4.94624615]
# c:\Users\aammar\miniconda3\envs\python_ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\aammar\miniconda3\envs\python_ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Classification

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# ## Binary Classification

# %%
# libraries import
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LogisticRegression
# load the data
df = sns.load_dataset('tips')
# select the feature column from df
X = df[['total_bill', 'size', 'tip']]
# select the target column from df
y = df['smoker']
# load/call the linear regression model
model = LogisticRegression()
# fit the model means train the model
model.fit(X, y)

# predict
model.predict([[50.527, 2, 5.67]])
# Out:
# c:\Users\aammar\miniconda3\envs\python_ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
# libraries import
import pandas as pd
import seaborn as sns
# import naive bayes
from sklearn.naive_bayes import GaussianNB
# load the data
df = sns.load_dataset('tips')
# select the feature column from df
X = df[['total_bill', 'size', 'tip']]
# select the target column from df
y = df['smoker']
# load/call the linear regression model
model = GaussianNB()
# fit the model means train the model
model.fit(X, y)

# predict
model.predict([[50.527, 2, 5.67]])
# Out:
# c:\Users\aammar\miniconda3\envs\python_ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype='<U3')

# %% [markdown]
# # Decision Trees

# %%
# libraries import
import pandas as pd
import seaborn as sns
# import naive bayes
from sklearn.naive_bayes import GaussianNB
# import decision tree
from sklearn.tree import DecisionTreeClassifier
# load the data
df = sns.load_dataset('tips')
# select the feature column from df
X = df[['total_bill', 'size', 'tip']]
# select the target column from df
y = df['smoker']
# load/call the linear regression model
model = DecisionTreeClassifier()
# fit the model means train the model
model.fit(X, y)

# predict
model.predict([[50.527, 2, 5.67]])
# Out:
# c:\Users\aammar\miniconda3\envs\python_ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
# Decision tree regressor
# libraries import
import pandas as pd
import seaborn as sns
# import decision tree
from sklearn.tree import DecisionTreeRegressor
# load the data
df = sns.load_dataset('tips')
df.head()

X = df[['total_bill', 'size']]
y = df['tip']

model = DecisionTreeRegressor()
model.fit(X, y)

model.predict([[50.527, 2]])
# Out:
# c:\Users\aammar\miniconda3\envs\python_ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([10.])

# %% [markdown]
# # Regression Metrics

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
# load the data
df = sns.load_dataset('tips')
df.head()

X = df[['total_bill', 'size']]
y = df['tip']

# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# call the model
model = LinearRegression()

# fit the model
model.fit(X_train, y_train)

# metric to evaluate the model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
y_pred = model.predict(X_test)

print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
print(f"R2 Score: {r2_score(y_test, y_pred)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error: {mean_absolute_percentage_error(y_test, y_pred)}")
# root mean squared error
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test, y_pred))}")
# Out:
# Mean Squared Error: 0.6485996190543517
# R2 Score: 0.4811084097989491
# Mean Absolute Error: 0.6639235737596483
# Mean Absolute Percentage Error: 0.27978917485910254
# Root Mean Squared Error: 0.8053568271607013
