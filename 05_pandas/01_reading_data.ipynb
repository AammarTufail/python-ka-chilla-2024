# %% [markdown]
# # Pandas library

# %% [markdown]
# <h2 style="font-family: 'poppins'; font-weight: bold; color: Yellow;">👨‍💻Author: Dr. Muhammad Aamamr Tufail</h2>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/AammarTufail)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/muhammadaammartufail)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/dr-muhammad-aammar-tufail-02471213b/)
#
# [![YouTube](https://img.shields.io/badge/YouTube-Profile-red?style=for-the-badge&logo=youtube)](https://www.youtube.com/@codanics)
# [![Facebook](https://img.shields.io/badge/Facebook-Profile-blue?style=for-the-badge&logo=facebook)](https://www.facebook.com/aammar.tufail)
# [![TikTok](https://img.shields.io/badge/TikTok-Profile-black?style=for-the-badge&logo=tiktok)](https://www.tiktok.com/@draammar)
#
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://twitter.com/aammar_tufail)
# [![Instagram](https://img.shields.io/badge/Instagram-Profile-blue?style=for-the-badge&logo=instagram)](https://www.instagram.com/aammartufail/)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:aammar@codanics.com)

# %% [markdown]
# Step-1: Importing the library

# %%
import pandas as pd

# %%
# importing data from clipboard
df = pd.read_clipboard()
df
# Out:
#        Name  Age  Weight
# 0  Muhammad   28      70
# 1       Ali   23      75
# 2     Ahmad   25      80
# 3   Minahil   27      65

# %% [markdown]
# # importing data from excel file

# %%
import pandas as pd
df_excel = pd.read_excel('../04_libraries/dataframes/titanic_df.xlsx', sheet_name=0) # sheet_name=0 is default you can also change the sheet name = "Sheet1"
df_excel
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd
df_excel = pd.read_excel('../00_datasets/titanic_df.xlsx')
df_excel
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # CSV and TSV files

# %%
# load csv data
df_csv = pd.read_csv('../00_datasets/titanic.csv')
df_csv
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# load tsv data
df_tsv = pd.read_csv('../00_datasets/titanic.tsv', sep='\t')
df_tsv
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Dummy Dataset

# %%
# create a dataframe from a dictionary for the people ages and names
data = {'Name': ['Muhammad', 'Ali', 'Ahmad', 'Minahil'],
        'Age': [28, 23, 25, 27],
        'Weight': [70, 75, 80, 65]
        }
data
df = pd.DataFrame(data)
df
# Out:
#        Name  Age  Weight
# 0  Muhammad   28      70
# 1       Ali   23      75
# 2     Ahmad   25      80
# 3   Minahil   27      65

# %%
df.to_clipboard()

# %%
df.to_excel('../00_datasets/people.xlsx', index=False)
df.to_csv('../00_datasets/people.csv', index=False)

# %% [markdown]
# # Advance Datset Reading from Excel

# %%
string = "Aammar\nAli\nAhmad\nMinahil"
print(string)
# Out:
# Aammar
# Ali
# Ahmad
# Minahil

# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\aammar\OneDrive\python_ka_chilla\00_datasets\pandas_practice\world_population_excel_workbook.xlsx')
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# > The `r` before the string in the `pd.read_excel` function call indicates that the string is a raw string literal. In Python, raw string literals treat backslashes `(\)` as literal characters and do not interpret them as escape characters.
# > This is useful for Windows file paths, where backslashes are common.

# %%
# read csv with spaces in name
df = pd.read_csv(r"C:\Users\aammar\OneDrive\python_ka_chilla\00_datasets\pandas_practice\countries of the world.csv")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %% [markdown]
# # Reading Tabluar Data

# %%
import pandas as pd

df_tabulated = pd.read_table("../00_datasets/titanic.tsv", sep="\t", header=0)
df_tabulated
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Json file reading

# %%
import pandas as pd
df = pd.read_json('../00_datasets/pandas_practice/json_sample.json')
df
# Out:
#                   title      genre       gross  imdb_metascore  popcorn_score  \
# 0             12 Strong     Action    $453,173              54             72
# 1     A Fantastic Woman      Drama     $87,000              78             83
# 2  Call Me By Your Name      Drama  $1,000,000              93             87
# 3          Paddington 2  Animation    $184,414              88             89
#
#   rating  tomato_score
# 0      R            54
# 1      R            90
# 2      R            96
# 3     PG           100
