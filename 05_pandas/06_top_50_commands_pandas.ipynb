# %% [markdown]
# # **Top-12 Steps and 50 commandas of Pandas for EDA analysis of anydata**

# %% [markdown]
# <h2 style="font-family: 'poppins'; font-weight: bold; color: Green;">👨‍💻Author: Dr. Muhammad Aamamr Tufail</h2>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/AammarTufail)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/muhammadaammartufail)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/dr-muhammad-aammar-tufail-02471213b/)
#
# [![YouTube](https://img.shields.io/badge/YouTube-Profile-red?style=for-the-badge&logo=youtube)](https://www.youtube.com/@codanics)
# [![Facebook](https://img.shields.io/badge/Facebook-Profile-blue?style=for-the-badge&logo=facebook)](https://www.facebook.com/aammar.tufail)
# [![TikTok](https://img.shields.io/badge/TikTok-Profile-black?style=for-the-badge&logo=tiktok)](https://www.tiktok.com/@draammar)
#
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://twitter.com/aammar_tufail)
# [![Instagram](https://img.shields.io/badge/Instagram-Profile-blue?style=for-the-badge&logo=instagram)](https://www.instagram.com/aammartufail/)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:aammar@codanics.com)

# %%
# Placeholder code to load Titanic dataset as df
import pandas as pd
import seaborn as sns
df = sns.load_dataset('titanic')

# %% [markdown]
# ## Step 1: Basic Data Inspection

# %% [markdown]
# ### Display the first few rows

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Display the last few rows

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ### Display a random sample

# %%
df.sample(5)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 344         0       2  male  36.0      0      0  13.0000        S  Second
# 188         0       3  male  40.0      1      1  15.5000        Q   Third
# 93          0       3  male  26.0      1      2  20.5750        S   Third
# 778         0       3  male   NaN      0      0   7.7375        Q   Third
# 388         0       3  male   NaN      0      0   7.7292        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# 344  man        True  NaN  Southampton    no   True
# 188  man        True  NaN   Queenstown    no  False
# 93   man        True  NaN  Southampton    no  False
# 778  man        True  NaN   Queenstown    no   True
# 388  man        True  NaN   Queenstown    no   True

# %% [markdown]
# ### Dataset info summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ### Statistical summary for numerical columns

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %% [markdown]
# ### Statistical summary for categorical columns

# %%
df.describe(include='O')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %% [markdown]
# ### Dataset dimensions

# %%
df.shape
# Out:
# (891, 15)

# %% [markdown]
# ### Column names

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %% [markdown]
# ### Data types of each column

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# convert who into category
df['who'] = df['who'].astype('category')
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who            category
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# ### Count missing values

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# find percentage of missing values
round(df.isnull().sum() / len(df) * 100, 2).sort_values(ascending=False)
# Out:
# deck           77.22
# age            19.87
# embarked        0.22
# embark_town     0.22
# survived        0.00
# pclass          0.00
# sex             0.00
# sibsp           0.00
# parch           0.00
# fare            0.00
# class           0.00
# who             0.00
# adult_male      0.00
# alive           0.00
# alone           0.00
# dtype: float64

# %% [markdown]
# ## Step 2: Handling Missing Values

# %% [markdown]
# ### Drop rows with any missing values

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# df.dropna()
# remove the deck column
# df.drop(columns='deck', inplace=True)
df = df.drop(columns='deck')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# ### Drop rows with specific missing values

# %%
df.dropna(subset=['age', 'embarked']) # just to show how to use subset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# ### Fill missing values with a fixed value

# %% [markdown]
# ### Fill missing values with the median

# %%
df['age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['age'].median()
# Out:
# np.float64(28.0)

# %%
df['age'] = df['age'].fillna(df['age'].median())

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ### Fill missing values with the mode

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df['embark_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ### Interpolate missing values

# %%
# df['age'].interpolate() # used only for numerical columns

# %% [markdown]
# ## Step 3: Duplicates and Data Integrity

# %% [markdown]
# ### Count duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(116)

# %%
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 409         0       3  female  28.0      3      1  25.4667        S   Third
# 857         1       1    male  51.0      0      0  26.5500        S   First
# 346         1       2  female  40.0      0      0  13.0000        S  Second
# 46          0       3    male  28.0      1      0  15.5000        Q   Third
# 543         1       2    male  32.0      1      0  26.0000        S  Second
#
#        who  adult_male  embark_town alive  alone
# 409  woman       False  Southampton    no  False
# 857    man        True  Southampton   yes   True
# 346  woman       False  Southampton   yes   True
# 46     man        True   Queenstown    no  False
# 543    man        True  Southampton   yes  False

# %% [markdown]
# ### Remove duplicate rows

# %%
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female  28.0      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# ### Get unique values in a column

# %%
df['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# ### Count unique values in a column

# %%
df['sex'].nunique()
# Out:
# 2

# %% [markdown]
# ## Step 4: Basic Data Composition

# %% [markdown]
# ### Frequency of values in a column

# %%
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %% [markdown]
# ### Proportion of values in a column

# %%
df['class'].value_counts(normalize=True)
# Out:
# class
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: proportion, dtype: float64

# %%
df['class'].value_counts(normalize=True) * 100
# Out:
# class
# Third     55.106622
# First     24.242424
# Second    20.650954
# Name: proportion, dtype: float64

# %% [markdown]
# ### Group size

# %%
df.groupby('class').size()
# Out:
# C:\Users\aammar\AppData\Local\Temp\ipykernel_6392\1820622143.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('class').size()
# class
# First     216
# Second    184
# Third     491
# dtype: int64

# %%
df.groupby(['class', 'sex']).size()
# Out:
# C:\Users\aammar\AppData\Local\Temp\ipykernel_6392\3645844081.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['class', 'sex']).size()
# class   sex
# First   female     94
#         male      122
# Second  female     76
#         male      108
# Third   female    144
#         male      347
# dtype: int64

# %%
df.groupby(['class', 'sex', 'class']).size()
# Out:
# C:\Users\aammar\AppData\Local\Temp\ipykernel_6392\1152377662.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['class', 'sex', 'class']).size()
# class   sex     class
# First   female  First      94
#                 Second      0
#                 Third       0
#         male    First     122
#                 Second      0
#                 Third       0
# Second  female  First       0
#                 Second     76
#                 Third       0
#         male    First       0
#                 Second    108
#                 Third       0
# Third   female  First       0
#                 Second      0
#                 Third     144
#         male    First       0
#                 Second      0
#                 Third     347
# dtype: int64

# %% [markdown]
# ## Step 5: Distribution Analysis

# %% [markdown]
# ### Summary for a specific column

# %%
df['fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %% [markdown]
# ### Bin value counts

# %%
df['fare'].value_counts()
# Out:
# fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
df['fare'].min()
# Out:
# np.float64(0.0)

# %%
df['fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['fare'].value_counts(bins=5)
# Out:
# (-0.513, 102.466]     838
# (102.466, 204.932]     33
# (204.932, 307.398]     17
# (409.863, 512.329]      3
# (307.398, 409.863]      0
# Name: count, dtype: int64

# %%
df['age'].value_counts(bins=5)
# Out:
# (16.336, 32.252]    523
# (32.252, 48.168]    188
# (0.339, 16.336]     100
# (48.168, 64.084]     69
# (64.084, 80.0]       11
# Name: count, dtype: int64

# %% [markdown]
# ### Histogram of a numerical column

# %%
df['age'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# ### Boxplot for outliers

# %%
df.boxplot(column='age')
# Out:
# <Axes: >

# %% [markdown]
# ## Step 6: Comparison and Group Analysis

# %% [markdown]
# ### Mean target by group

# %%
df.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %% [markdown]
# ### Group size for multiple columns

# %%
df.groupby(['class', 'sex']).size()
# Out:
# C:\Users\aammar\AppData\Local\Temp\ipykernel_6392\3645844081.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['class', 'sex']).size()
# class   sex
# First   female     94
#         male      122
# Second  female     76
#         male      108
# Third   female    144
#         male      347
# dtype: int64

# %% [markdown]
# ### Pivot table for comparison

# %%
df.pivot_table('survived', index='class', columns='sex')
# Out:
# C:\Users\aammar\AppData\Local\Temp\ipykernel_6392\4259812463.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table('survived', index='class', columns='sex')
# sex       female      male
# class
# First   0.968085  0.368852
# Second  0.921053  0.157407
# Third   0.500000  0.135447

# %% [markdown]
# ### Aggregate statistics by group

# %%
df.groupby('class').agg({'fare': ['mean', 'median']})
# Out:
# C:\Users\aammar\AppData\Local\Temp\ipykernel_6392\4182075157.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('class').agg({'fare': ['mean', 'median']})
#              fare
#              mean   median
# class
# First   84.154687  60.2875
# Second  20.662183  14.2500
# Third   13.675550   8.0500

# %% [markdown]
# ## Step 7: Feature Engineering

# %% [markdown]
# ### Create a new column

# %%
df['family_size'] = df['sibsp'] + df['parch']
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  family_size
# 0    man        True  Southampton    no  False            1
# 1  woman       False    Cherbourg   yes  False            1
# 2  woman       False  Southampton   yes   True            0
# 3  woman       False  Southampton   yes  False            1
# 4    man        True  Southampton    no   True            0

# %% [markdown]
# ### Bin numerical data into categories

# %%
df['age_group'] = pd.cut(df['age'], bins=[0, 12, 18, 50, 80], labels=['Child', "Teenager", 'Adult', 'Senior'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  family_size age_group
# 0    man        True  Southampton    no  False            1     Adult
# 1  woman       False    Cherbourg   yes  False            1     Adult
# 2  woman       False  Southampton   yes   True            0     Adult
# 3  woman       False  Southampton   yes  False            1     Adult
# 4    man        True  Southampton    no   True            0     Adult

# %%
df['age_group'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='age_group'>

# %% [markdown]
# ### Convert a column to categorical type

# %%
df['class'] = df['class'].astype('category')

# %% [markdown]
# ## Step 8: Filtering and Selection

# %% [markdown]
# ### Filter rows by condition

# %%
df[df['age'] > 18]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ### Select rows by condition with `.loc`

# %%
df.loc[df['survived'] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
# ...

# %% [markdown]
# ### Select rows and columns by index with `.iloc`

# %%
df.iloc[0:5, 0:3]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
# 3         1       1  female
# 4         0       3    male

# %% [markdown]
# ## Step 9: Sorting and Ranking

# %% [markdown]
# ### Sort by a column

# %%
df.sort_values('age', ascending=True)
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 803         1       3    male   0.42      0      1   8.5167        C   Third
# 755         1       2    male   0.67      1      1  14.5000        S  Second
# 644         1       3  female   0.75      2      1  19.2583        C   Third
# 469         1       3  female   0.75      2      1  19.2583        C   Third
# 831         1       2    male   0.83      1      1  18.7500        S  Second
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 116         0       3    male  70.50      0      0   7.7500        Q   Third
# 96          0       1    male  71.00      0      0  34.6542        C   First
# 493         0       1    male  71.00      0      0  49.5042        C   First
# 851         0       3    male  74.00      0      0   7.7750        S   Third
# 630         1       1    male  80.00      0      0  30.0000        S   First
#
# ...

# %% [markdown]
# ### Sort by multiple columns

# %%
df.sort_values(['class', 'fare'], ascending=[True, False])
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 378         0       3    male  20.0      0      0    4.0125        C  Third
# 179         0       3    male  36.0      0      0    0.0000        S  Third
# 271         1       3    male  25.0      0      0    0.0000        S  Third
# 302         0       3    male  19.0      0      0    0.0000        S  Third
# 597         0       3    male  49.0      0      0    0.0000        S  Third
#
# ...

# %% [markdown]
# ### Get the top 5 largest values

# %%
df.nlargest(5, 'fare')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
#
#        who  adult_male  embark_town alive  alone  family_size age_group
# 258  woman       False    Cherbourg   yes   True            0     Adult
# 679    man        True    Cherbourg   yes  False            1     Adult
# 737    man        True    Cherbourg   yes   True            0     Adult
# 27     man        True  Southampton    no  False            5     Adult
# 88   woman       False  Southampton   yes  False            5     Adult

# %% [markdown]
# ### Get the top 5 smallest values

# %%
df.nsmallest(15, 'fare')
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 179         0       3  male  36.0      0      0   0.0        S   Third  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 277         0       2  male  28.0      0      0   0.0        S  Second  man
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
# 413         0       2  male  28.0      0      0   0.0        S  Second  man
# 466         0       2  male  28.0      0      0   0.0        S  Second  man
# 481         0       2  male  28.0      0      0   0.0        S  Second  man
# 597         0       3  male  49.0      0      0   0.0        S   Third  man
# 633         0       1  male  28.0      0      0   0.0        S   First  man
# 674         0       2  male  28.0      0      0   0.0        S  Second  man
# ...

# %% [markdown]
# ## Step 10: Correlation and Relationships

# %% [markdown]
# ### Correlation matrix

# %%
df[['age', 'fare']].corr() # only on numeric columns
# Out:
#            age      fare
# age   1.000000  0.096688
# fare  0.096688  1.000000

# %% [markdown]
# ### Covariance matrix

# %%
df[['age', 'fare']].cov()
# Out:
#              age         fare
# age   169.512498    62.556767
# fare   62.556767  2469.436846

# %% [markdown]
# ### Correlation with a specific column

# %%
sns.pairplot(df)

# %% [markdown]
# ### Correlation between specific columns

# %%
df[['age', 'fare']].corr()
# Out:
#            age      fare
# age   1.000000  0.096688
# fare  0.096688  1.000000

# %% [markdown]
# ## Step 11: Exporting and Saving

# %% [markdown]
# ### Export to CSV

# %%
df.to_csv('../00_datasets/pandas_practice/titanic_clean.csv', index=False)

# %% [markdown]
# ### Export to Excel

# %%
df.to_excel('../00_datasets/pandas_practice/titanic_clean.xlsx', index=False)

# %% [markdown]
# ### Export to JSON

# %%
df.to_json('../00_datasets/pandas_practice/titanic_clean.json')

# %% [markdown]
# ## Step 12: Extra Commands for Quick Insights

# %% [markdown]
# ### Memory usage of each column

# %%
df.memory_usage(deep=True)
# Out:
# Index            128
# survived        7128
# pclass          7128
# sex            54979
# age             7128
# sibsp           7128
# parch           7128
# fare            7128
# embarked       51678
# class           1186
# who             1183
# adult_male       891
# embark_town    60175
# alive          52911
# alone            891
# family_size     7128
# age_group       1315
# dtype: int64

# %% [markdown]
# ### Apply a function to each value in a column

# %%
df['fare_plus_10'] = df['fare'].apply(lambda x: x + 10)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  family_size age_group  \
# 0    man        True  Southampton    no  False            1     Adult
# 1  woman       False    Cherbourg   yes  False            1     Adult
# 2  woman       False  Southampton   yes   True            0     Adult
# 3  woman       False  Southampton   yes  False            1     Adult
# 4    man        True  Southampton    no   True            0     Adult
#
#    fare_plus_10
# 0       17.2500
# 1       81.2833
# 2       17.9250
# 3       63.1000
# 4       18.0500
